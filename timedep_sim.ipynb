# %% [markdown]
# <a href="https://colab.research.google.com/github/paulinajv/DWI-DTI-processing/blob/main/timedep_sim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install disimpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 18.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for disimpy: filename=disimpy-0.3.0-py3-none-any.whl size=1836666 sha256=fcba3d3d63e4210e1682f1047c64e5b5ee04d4b228304e87f5b5e3acda104a6c
#   Stored in directory: /root/.cache/pip/wheels/ff/f8/1c/3bb0bbaf838d5bf4bf6a28cac3c9a6dd487a5a17aec460c7ce
# Successfully built disimpy
# ...

# %%
# Import the packages and modules used in this tutorial

import os
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from disimpy import gradients, simulations, substrates, utils

os.chdir(r'C:\Users\z34213pv\The University of Manchester Dropbox\Paulina Villasenor\camino_sim')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-300802757.py in <cell line: 0>()
#       9 from disimpy import gradients, simulations, substrates, utils
#      10
# ---> 11 os.chdir(r'C:\Users\z34213pv\The University of Manchester Dropbox\Paulina Villasenor\camino_sim')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\z34213pv\\The University of Manchester Dropbox\\Paulina Villasenor\\camino_sim'

# %%
n_walkers = int(1e3)
diffusivity = 2e-9  # SI units (m^2/s)
